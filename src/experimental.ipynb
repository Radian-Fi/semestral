# %%
include("experimental.jl")
# Out:
# run_main (generic function with 4 methods)

# %%
filename1 = "/media/radian-fi/KINGSTON/VIZ/Blackhole/el2_512_512_512.csv"
filename2 = "/media/radian-fi/KINGSTON/VIZ/Blackhole/mag2_512_512_512.csv"
subsample = 4
# Out:
# 4

# %%
# run_main(filename1, filename2, subsample)

# %%
elbound, elfield, elbhcenter, elbhr = read_dataset(filename1, subsample)
magbound, magfield, magbhcenter, magbhr = read_dataset(filename2, subsample)
println(elbound)
# arrows_and_streamplot_in_3d()
# Out:
# Float32[-0.57568, 1.746, 1.884]
# Float32[0.74229, -1.3874, 1.588]
# Float32[1.3553, 0.77963, -0.012606]
# Float32[2.5662, -2.4381, 0.27844]
# (0.20763:0.010176141732283464:1.5, -2.6918:0.010959055118110237:-1.3, -0.88943:0.01409:0.9)

# %%
visualize_main(elbound, elfield, elbhcenter, elbhr, magbound, magfield, magbhcenter, magbhr)
# Out:
# (0.04608375000000001 .. 1.66154625, -2.865775 .. -1.126025, -1.11310875 .. 1.12367875)
# (1.1638094f0, 15.215002f0)
# (0.008778711f0, 15.764921f0)
# (0.5, 1.0)
